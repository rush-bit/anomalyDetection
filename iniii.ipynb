# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv('allcars.csv',low_memory=False)
df2=pd.read_csv('v2.csv',low_memory=False)

# %%
df1.head()
# Out:
#    Unnamed: 0                   timeStamp  tripID  \
# 0           0  2017-10-31 18:45:59.000000       0
# 1           1  2017-10-31 18:46:00.000000       0
# 2           2  2017-10-31 18:46:01.000000       0
# 3           3  2017-10-31 18:46:02.000000       0
# 4           4  2017-10-31 18:46:03.000000       0
#
#                                              accData  gps_speed  battery  \
# 0  ffb0fd700220fff43fffe74808e73e03f33400ef33fbe1...        2.2    14.48
# 1  00b0fda802e804e14104ed3d01ee3a08ec4c04f738fbd5...        3.7    14.48
# 2  00f0fe5002b0fdea4009e33c01ed3701ec4100f53b05e8...        3.9    14.54
# 3  0120fdc0028804e03c10de3a09e8400ce43b0ae63b01f4...        3.9    14.56
# 4  00a0fde802d816e0370ae73604e23b04e53900e542ffea...        4.7    14.48
#
#    cTemp  dtc      eLoad  iat  imap  kpl  maf     rpm  speed  tAdv       tPos  \
# 0    NaN  NaN  44.313725  NaN   NaN  0.0  0.0   903.0    4.0   NaN  15.686275
# ...

# %%
df2.head()
# Out:
#   tripID deviceID            timeStamp  \
# 0      1      0.0  2017-12-22 18:43:05
# 1      1      0.0  2017-12-22 18:43:06
# 2      1      0.0  2017-12-22 18:43:07
# 3      1      0.0  2017-12-22 18:43:08
# 4      1      0.0  2017-12-22 18:43:09
#
#                                              accData gps_speed battery cTemp  \
# 0  10c0f8e00448fa18c80515d30000000000000000000000...   24.2612     0.0  66.0
# 1  1138f8c804780a1ebdf718bcf919d10617c8e301b31017...     23.15     0.0  66.0
# 2  10f0f89804480612c30010c30714ce0520b7f41dbdf118...   18.7052     0.0  66.0
# 3  10d0f84804480d15bd0210c9f822c80017caf81ccd0517...   16.4828     0.0  66.0
# 4  1090f8c80480041dc9081cc50815c60511c60112c40514...   17.4088     0.0  66.0
#
#    dtc    eLoad   iat  imap  kpl  maf      rpm speed tAdv tPos
# 0  0.0  28.6275  40.0  97.0  0.0  0.0  1010.75  23.0  0.0  0.0
# 1  0.0  33.7255  40.0  98.0  0.0  0.0    815.5  21.0  0.0  0.0
# 2  0.0  43.1373  40.0  98.0  0.0  0.0   862.25  17.0  0.0  0.0
# ...

# %%
df3=pd.read_csv('fleet_features.csv',low_memory=False)

# %%
df3.head()
# Out:
#    deviceID  tripID  speed_mean  speed_max  speed_std  rpm_mean  rpm_max  \
# 0         1       0   -0.094017       89.0  31.508224  1.134219   3829.0
# 1         1       1    1.306837      157.0        NaN  7.194329   5508.5
# 2         1      10    1.306837      157.0   0.000000  7.194329   5508.5
# 3         1      11   -0.614124        0.0   0.000000 -1.154932      0.0
# 4         1      12   -0.520727       59.0  13.100278 -0.332544   4010.5
#
#       rpm_std  acceleration_mean  acceleration_max  acceleration_std  \
# 0  908.289244          -0.019588               6.0          1.547410
# 1         NaN          -0.011293               0.0               NaN
# 2    0.000000          -0.011293               0.0          0.000000
# 3    0.000000          -0.011294               0.0          0.000013
# 4  793.698729          -0.029947               7.0          1.459695
#
#    kpl_mean   kpl_min
# 0  0.000000  0.000000
# 1  3.540058  3.540058
# 2  3.540058  3.540058
# ...

# %%
df4=pd.read_csv('clustered_features.csv',low_memory=False)

# %%
df4[df4['cluster']==1]
# Out:
#       deviceID  tripID  speed_mean  speed_max  speed_std  rpm_mean  rpm_max  \
# 0            1       0   -0.094017       89.0  31.508224  1.134219   3829.0
# 1            1       1    1.306837      157.0        NaN  7.194329   5508.5
# 2            1      10    1.306837      157.0   0.000000  7.194329   5508.5
# 3            1      11   -0.614124        0.0   0.000000 -1.154932      0.0
# 4            1      12   -0.520727       59.0  13.100278 -0.332544   4010.5
# ...        ...     ...         ...        ...        ...       ...      ...
# 4806         8       0   -0.614124        0.0   0.000000 -1.154932      0.0
# 4807         8      66   -0.614124        0.0        NaN -1.154932      0.0
# 4808         8      67   -0.614124        0.0   0.000000 -1.154932      0.0
# 4809         8      68   -0.614124        0.0   0.000000 -1.154932      0.0
# 4810         8      69   -0.614124        0.0   0.000000 -1.154932      0.0
#
# ...

# %%
df4[df4['cluster']==2]
# Out:
#       deviceID  tripID  speed_mean  speed_max   speed_std  rpm_mean  rpm_max  \
# 257         12     200    2.505908      255.0    0.000000 -0.768427    255.0
# 288         12      49    2.505908      255.0    0.000000 -0.768427    255.0
# 290         12      50    2.505908      255.0    0.000000 -0.768427    255.0
# 554         16       0    2.505908      255.0    0.000000 -0.768427    255.0
# 682         22       0    2.505908      255.0    0.000000 -0.768427    255.0
# ...        ...     ...         ...        ...         ...       ...      ...
# 3770        50      35    2.505908      255.0    0.000000 -0.768427    255.0
# 3774        51     146    0.875538      255.0  140.898013 -0.140167    814.0
# 3776        51       3    1.587848      255.0  115.209336 -0.398490   2104.0
# 4147        53     387    2.505908      255.0    0.000000 -0.768427    255.0
# 4148        53     388    2.505908      255.0    0.000000 -0.768427    255.0
#
# ...
